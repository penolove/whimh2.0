# %%
import matplotlib.pyplot as plt
import numpy as np

# %matplotlib inline
plt.rcParams['figure.figsize'] = (10.0, 8.0) # set default size of plots
plt.rcParams['image.interpolation'] = 'nearest'
plt.rcParams['image.cmap'] = 'gray'

# %%
frames=np.load("outfile_x.npy")
y_train=np.load("outfile_y.npy")

# %%
classes = ['min-han','not_mh','not_human']
num_classes = 3
samples_per_class = 5
for y, cls in enumerate(classes):
    idxs = np.flatnonzero(y_train == y)
    idxs = np.random.choice(idxs, samples_per_class, replace=False)
    for i, idx in enumerate(idxs):
        plt_idx = i * num_classes + y + 1
        plt.subplot(samples_per_class, num_classes, plt_idx)
        plt.imshow(frames[idx].astype('uint8'))
        plt.axis('off')
        if i == 0:
            plt.title(cls)
plt.show()

# %%
arr = np.arange(len(frames))
np.random.shuffle(arr)
x_train=frames[arr]
y_train=y_train[arr].astype('uint8')

x_train_temp = np.empty((x_train.shape[0],x_train.shape[3],x_train.shape[1],x_train.shape[2]))
print "there are "+ str(x_train.shape[0]) + " images"
for j in range(x_train.shape[0]):
    for i in range(x_train.shape[3]):
        x_train_temp[j,i,:,:]=x_train[j,:,:,i]
x_train=x_train_temp

data={
  'X_train': x_train[:int(len(x_train)*0.8)],
  'y_train': y_train[:int(len(x_train)*0.8)],
  'X_val': x_train[int(len(x_train)*0.8):],
  'y_val': y_train[int(len(x_train)*0.8):],
}
# Out:
# there are 963 images

# %%
#this cell will load pretrained model
import pickle 
with open('Whimh_model.dkl','rb') as input:
    model=pickle.load(input)

# %%
#using models maked in cs231n assignment2
from cs231n.classifiers.cnn import *
from cs231n.data_utils import get_CIFAR10_data
from cs231n.gradient_check import eval_numerical_gradient_array, eval_numerical_gradient
from cs231n.layers import *
from cs231n.fast_layers import *
from cs231n.solver import Solver

# %%
#over fitting at small data
from cs231n.classifiers.cnn import *

num_train = 50
small_data = {
  'X_train': data['X_train'][:num_train],
  'y_train': data['y_train'][:num_train],
  'X_val': data['X_val'],
  'y_val': data['y_val'],
}

model = ThreeLayerConvNet(weight_scale=1e-2)

#model = ConvNet(hidden_dims=[32,32,32],dropout=0,use_batchnorm=False,reg=0.001,pool_period=3)

solver = Solver(model, small_data,
                num_epochs=12, batch_size=50,
                update_rule='adam',
                optim_config={
                  'learning_rate': 1e-3,
                },
                verbose=True, print_every=10)
solver.train()
# Out:
# (Iteration 1 / 12) loss: 2.325154
# (Epoch 1 / 12) train acc: 0.680000; val_acc: 0.538860
# (Epoch 2 / 12) train acc: 0.700000; val_acc: 0.554404
# (Epoch 3 / 12) train acc: 0.740000; val_acc: 0.585492
# (Epoch 4 / 12) train acc: 0.760000; val_acc: 0.626943
# (Epoch 5 / 12) train acc: 0.860000; val_acc: 0.652850
# (Epoch 6 / 12) train acc: 0.880000; val_acc: 0.689119
# (Epoch 7 / 12) train acc: 0.940000; val_acc: 0.678756
# (Epoch 8 / 12) train acc: 0.940000; val_acc: 0.694301
# (Epoch 9 / 12) train acc: 0.980000; val_acc: 0.689119
# (Epoch 10 / 12) train acc: 0.980000; val_acc: 0.761658
# (Iteration 11 / 12) loss: 0.130843
# (Epoch 11 / 12) train acc: 0.980000; val_acc: 0.746114
# (Epoch 12 / 12) train acc: 0.960000; val_acc: 0.746114

# %%
#model = ConvNet(hidden_dims=[64,64,128,128,256,256,512,512],hidden_dim=[4096,4096,1000],
#                dropout=0.6,use_batchnorm=True,reg=1e-4,pool_period=2)
#model = ConvNet(hidden_dims=[16],hidden_dim=[15],
#                dropout=0.1,use_batchnorm=False,reg=0.5,pool_period=2)
model = ConvNet(hidden_dims=[64,128,256],hidden_dim=[1024,500],
                dropout=0.5,use_batchnorm=False,reg=2*1e-4,pool_period=1,num_classes=3)

# %%
solver = Solver(model, data,
                num_epochs=15, batch_size=60,
                update_rule='adam',
                optim_config={
                  'learning_rate': 1e-3,
                },
                verbose=True, print_every=30)
solver.train()
# Out:
# (Iteration 1 / 360) loss: 1.145326
# (Epoch 0 / 30) train acc: 0.562338; val_acc: 0.502591
# (Epoch 1 / 30) train acc: 0.562338; val_acc: 0.502591
# (Epoch 2 / 30) train acc: 0.562338; val_acc: 0.502591
# (Iteration 31 / 360) loss: 1.060908
# (Epoch 3 / 30) train acc: 0.562338; val_acc: 0.502591
# (Epoch 4 / 30) train acc: 0.585714; val_acc: 0.585492
# (Epoch 5 / 30) train acc: 0.727273; val_acc: 0.730570
# (Iteration 61 / 360) loss: 0.838986
# (Epoch 6 / 30) train acc: 0.523377; val_acc: 0.528497
# (Epoch 7 / 30) train acc: 0.698701; val_acc: 0.704663
# (Iteration 91 / 360) loss: 0.762640
# (Epoch 8 / 30) train acc: 0.677922; val_acc: 0.689119
# (Epoch 9 / 30) train acc: 0.775325; val_acc: 0.761658
# (Epoch 10 / 30) train acc: 0.828571; val_acc: 0.808290
# (Iteration 121 / 360) loss: 0.631706
# (Epoch 11 / 30) train acc: 0.727273; val_acc: 0.746114
# (Epoch 12 / 30) train acc: 0.793506; val_acc: 0.782383
# (Iteration 151 / 360) loss: 0.370595
# (Epoch 13 / 30) train acc: 0.761039; val_acc: 0.746114
# (Epoch 14 / 30) train acc: 0.832468; val_acc: 0.803109
# (Epoch 15 / 30) train acc: 0.838961; val_acc: 0.808290
# (Iteration 181 / 360) loss: 0.683106
# (Epoch 16 / 30) train acc: 0.823377; val_acc: 0.792746
# (Epoch 17 / 30) train acc: 0.833766; val_acc: 0.813472
# (Iteration 211 / 360) loss: 0.661366
# (Epoch 18 / 30) train acc: 0.806494; val_acc: 0.792746
# (Epoch 19 / 30) train acc: 0.858442; val_acc: 0.834197
# (Epoch 20 / 30) train acc: 0.838961; val_acc: 0.818653
# (Iteration 241 / 360) loss: 0.498857
# (Epoch 21 / 30) train acc: 0.867532; val_acc: 0.865285
# (Epoch 22 / 30) train acc: 0.840260; val_acc: 0.834197
# (Iteration 271 / 360) loss: 0.462206
# (Epoch 23 / 30) train acc: 0.875325; val_acc: 0.834197
# (Epoch 24 / 30) train acc: 0.798701; val_acc: 0.751295
# (Epoch 25 / 30) train acc: 0.838961; val_acc: 0.792746
# (Iteration 301 / 360) loss: 0.343709
# (Epoch 26 / 30) train acc: 0.842857; val_acc: 0.782383
# (Epoch 27 / 30) train acc: 0.871429; val_acc: 0.834197
# (Iteration 331 / 360) loss: 0.339634
# (Epoch 28 / 30) train acc: 0.805195; val_acc: 0.746114
# (Epoch 29 / 30) train acc: 0.900000; val_acc: 0.875648
# (Epoch 30 / 30) train acc: 0.863636; val_acc: 0.813472

# %%
plt.subplot(2, 1, 1)
plt.plot(solver.loss_history, 'o')
plt.xlabel('iteration')
plt.ylabel('loss')

plt.subplot(2, 1, 2)
plt.plot(solver.train_acc_history, '-o')
plt.plot(solver.val_acc_history, '-o')
plt.legend(['train', 'val'], loc='upper left')
plt.xlabel('epoch')
plt.ylabel('accuracy')
plt.show()

# %%
#using model to predict Validation_set
test_result=model.loss(data['X_val'])
import pandas
clasName=['min-han','mh_not','not_human']
pairVal=zip(data['y_val'],np.argmax(test_result, axis=1))
ps = pandas.Series([(clasName[i[0]],clasName[i[1]]) for i in pairVal])
counts = ps.value_counts()
print "ground_truth v.s. predict"
print counts
# Out:
# ground_truth v.s. predict
# (mh_not, mh_not)          84
# (not_human, not_human)    69
# (min-han, min-han)        16
# (min-han, mh_not)         10
# (mh_not, not_human)       10
# (mh_not, min-han)          3
# (min-han, not_human)       1
# dtype: int64

# %%
solver = Solver(model, data,
                num_epochs=15, batch_size=60,
                update_rule='adam',
                optim_config={
                  'learning_rate': 5*1e-4,
                },
                verbose=True, print_every=30)
solver.train()
# Out:
# (Iteration 1 / 360) loss: 0.237532
# (Epoch 30 / 30) train acc: 0.890909; val_acc: 0.880829
# (Epoch 31 / 30) train acc: 0.897403; val_acc: 0.849741
# (Epoch 32 / 30) train acc: 0.816883; val_acc: 0.777202
# (Iteration 31 / 360) loss: 0.397916
# (Epoch 33 / 30) train acc: 0.868831; val_acc: 0.803109
# (Epoch 34 / 30) train acc: 0.788312; val_acc: 0.740933
# (Epoch 35 / 30) train acc: 0.892208; val_acc: 0.849741
# (Iteration 61 / 360) loss: 0.291618
# (Epoch 36 / 30) train acc: 0.876623; val_acc: 0.818653
# (Epoch 37 / 30) train acc: 0.864935; val_acc: 0.834197
# (Iteration 91 / 360) loss: 0.233065
# (Epoch 38 / 30) train acc: 0.893506; val_acc: 0.839378
# (Epoch 39 / 30) train acc: 0.871429; val_acc: 0.823834
# (Epoch 40 / 30) train acc: 0.870130; val_acc: 0.823834
# (Iteration 121 / 360) loss: 0.291057
# (Epoch 41 / 30) train acc: 0.905195; val_acc: 0.849741
# (Epoch 42 / 30) train acc: 0.922078; val_acc: 0.865285
# (Iteration 151 / 360) loss: 0.219687
# (Epoch 43 / 30) train acc: 0.916883; val_acc: 0.865285
# (Epoch 44 / 30) train acc: 0.845455; val_acc: 0.808290
# (Epoch 45 / 30) train acc: 0.919481; val_acc: 0.875648
# (Iteration 181 / 360) loss: 0.196538
# (Epoch 46 / 30) train acc: 0.928571; val_acc: 0.875648
# (Epoch 47 / 30) train acc: 0.922078; val_acc: 0.875648
# (Iteration 211 / 360) loss: 0.246249
# (Epoch 48 / 30) train acc: 0.937662; val_acc: 0.906736
# (Epoch 49 / 30) train acc: 0.937662; val_acc: 0.875648
# (Epoch 50 / 30) train acc: 0.931169; val_acc: 0.891192
# (Iteration 241 / 360) loss: 0.201488
# (Epoch 51 / 30) train acc: 0.931169; val_acc: 0.865285
# (Epoch 52 / 30) train acc: 0.924675; val_acc: 0.870466
# (Iteration 271 / 360) loss: 0.143983
# (Epoch 53 / 30) train acc: 0.940260; val_acc: 0.880829
# (Epoch 54 / 30) train acc: 0.935065; val_acc: 0.886010
# (Epoch 55 / 30) train acc: 0.928571; val_acc: 0.870466
# (Iteration 301 / 360) loss: 0.260872
# (Epoch 56 / 30) train acc: 0.907792; val_acc: 0.886010
# (Epoch 57 / 30) train acc: 0.950649; val_acc: 0.875648
# (Iteration 331 / 360) loss: 0.169544
# (Epoch 58 / 30) train acc: 0.950649; val_acc: 0.875648
# (Epoch 59 / 30) train acc: 0.925974; val_acc: 0.870466
# (Epoch 60 / 30) train acc: 0.946753; val_acc: 0.886010

# %%
plt.subplot(2, 1, 1)
plt.plot(solver.loss_history, 'o')
plt.xlabel('iteration')
plt.ylabel('loss')

plt.subplot(2, 1, 2)
plt.plot(solver.train_acc_history, '-o')
plt.plot(solver.val_acc_history, '-o')
plt.legend(['train', 'val'], loc='upper left')
plt.xlabel('epoch')
plt.ylabel('accuracy')
plt.show()

# %%
#using model to predict Validation_set
test_result=model.loss(data['X_val'])
import pandas
clasName=['min-han','mh_not','not_human']
pairVal=zip(data['y_val'],np.argmax(test_result, axis=1))
ps = pandas.Series([(clasName[i[0]],clasName[i[1]]) for i in pairVal])
counts = ps.value_counts()
print "ground_truth v.s. predict"
print counts
# Out:
# ground_truth v.s. predict
# (mh_not, mh_not)          88
# (not_human, not_human)    68
# (min-han, min-han)        19
# (min-han, mh_not)          8
# (mh_not, min-han)          5
# (mh_not, not_human)        4
# (not_human, min-han)       1
# dtype: int64

# %%
solver = Solver(model, data,
                num_epochs=30, batch_size=60,
                update_rule='adam',
                optim_config={
                  'learning_rate': 1e-4,
                },
                verbose=True, print_every=30)
solver.train()
# Out:
# (Iteration 1 / 360) loss: 0.381558
# (Epoch 60 / 30) train acc: 0.944156; val_acc: 0.886010
# (Epoch 61 / 30) train acc: 0.938961; val_acc: 0.875648
# (Epoch 62 / 30) train acc: 0.901299; val_acc: 0.865285
# (Iteration 31 / 360) loss: 0.226931
# (Epoch 63 / 30) train acc: 0.922078; val_acc: 0.880829
# (Epoch 64 / 30) train acc: 0.918182; val_acc: 0.849741
# (Epoch 65 / 30) train acc: 0.945455; val_acc: 0.896373
# (Iteration 61 / 360) loss: 0.267943
# (Epoch 66 / 30) train acc: 0.938961; val_acc: 0.880829
# (Epoch 67 / 30) train acc: 0.932468; val_acc: 0.865285
# (Iteration 91 / 360) loss: 0.212618
# (Epoch 68 / 30) train acc: 0.951948; val_acc: 0.886010
# (Epoch 69 / 30) train acc: 0.914286; val_acc: 0.860104
# (Epoch 70 / 30) train acc: 0.954545; val_acc: 0.886010
# (Iteration 121 / 360) loss: 0.307944
# (Epoch 71 / 30) train acc: 0.950649; val_acc: 0.891192
# (Epoch 72 / 30) train acc: 0.925974; val_acc: 0.870466
# (Iteration 151 / 360) loss: 0.242245
# (Epoch 73 / 30) train acc: 0.955844; val_acc: 0.886010
# (Epoch 74 / 30) train acc: 0.937662; val_acc: 0.891192
# (Epoch 75 / 30) train acc: 0.916883; val_acc: 0.886010
# (Iteration 181 / 360) loss: 0.259775
# (Epoch 76 / 30) train acc: 0.957143; val_acc: 0.896373
# (Epoch 77 / 30) train acc: 0.916883; val_acc: 0.865285
# (Iteration 211 / 360) loss: 0.262202
# (Epoch 78 / 30) train acc: 0.940260; val_acc: 0.886010
# (Epoch 79 / 30) train acc: 0.963636; val_acc: 0.896373
# (Epoch 80 / 30) train acc: 0.941558; val_acc: 0.880829
# (Iteration 241 / 360) loss: 0.275166
# (Epoch 81 / 30) train acc: 0.938961; val_acc: 0.880829
# (Epoch 82 / 30) train acc: 0.958442; val_acc: 0.901554
# (Iteration 271 / 360) loss: 0.146630
# (Epoch 83 / 30) train acc: 0.967532; val_acc: 0.901554
# (Epoch 84 / 30) train acc: 0.967532; val_acc: 0.906736
# (Epoch 85 / 30) train acc: 0.958442; val_acc: 0.875648
# (Iteration 301 / 360) loss: 0.257563
# (Epoch 86 / 30) train acc: 0.970130; val_acc: 0.917098
# (Epoch 87 / 30) train acc: 0.970130; val_acc: 0.922280
# (Iteration 331 / 360) loss: 0.257137
# (Epoch 88 / 30) train acc: 0.957143; val_acc: 0.901554
# (Epoch 89 / 30) train acc: 0.953247; val_acc: 0.886010
# (Epoch 90 / 30) train acc: 0.968831; val_acc: 0.906736

# %%
plt.subplot(2, 1, 1)
plt.plot(solver.loss_history, 'o')
plt.xlabel('iteration')
plt.ylabel('loss')

plt.subplot(2, 1, 2)
plt.plot(solver.train_acc_history, '-o')
plt.plot(solver.val_acc_history, '-o')
plt.legend(['train', 'val'], loc='upper left')
plt.xlabel('epoch')
plt.ylabel('accuracy')
plt.show()

# %%
#using model to predict Validation_set
test_result=model.loss(data['X_val'])
import pandas
clasName=['min-han','mh_not','not_human']
pairVal=zip(data['y_val'],np.argmax(test_result, axis=1))
ps = pandas.Series([(clasName[i[0]],clasName[i[1]]) for i in pairVal])
counts = ps.value_counts()
print "ground_truth v.s. predict"
print counts
# Out:
# ground_truth v.s. predict
# (mh_not, mh_not)          90
# (not_human, not_human)    69
# (min-han, min-han)        19
# (min-han, mh_not)          7
# (mh_not, min-han)          5
# (mh_not, not_human)        2
# (min-han, not_human)       1
# dtype: int64

# %%
solver = Solver(model, data,
                num_epochs=30, batch_size=60,
                update_rule='adam',
                optim_config={
                  'learning_rate': 5*1e-5,
                },
                verbose=True, print_every=30)
solver.train()
# Out:
# (Iteration 1 / 360) loss: 0.207719
# (Epoch 90 / 30) train acc: 0.966234; val_acc: 0.911917
# (Epoch 91 / 30) train acc: 0.971429; val_acc: 0.917098
# (Epoch 92 / 30) train acc: 0.951948; val_acc: 0.870466
# (Iteration 31 / 360) loss: 0.217029
# (Epoch 93 / 30) train acc: 0.955844; val_acc: 0.886010
# (Epoch 94 / 30) train acc: 0.957143; val_acc: 0.891192
# (Epoch 95 / 30) train acc: 0.974026; val_acc: 0.911917
# (Iteration 61 / 360) loss: 0.252151
# (Epoch 96 / 30) train acc: 0.966234; val_acc: 0.886010
# (Epoch 97 / 30) train acc: 0.976623; val_acc: 0.917098
# (Iteration 91 / 360) loss: 0.145598
# (Epoch 98 / 30) train acc: 0.974026; val_acc: 0.896373
# (Epoch 99 / 30) train acc: 0.977922; val_acc: 0.896373
# (Epoch 100 / 30) train acc: 0.980519; val_acc: 0.906736
# (Iteration 121 / 360) loss: 0.221207
# (Epoch 101 / 30) train acc: 0.968831; val_acc: 0.922280
# (Epoch 102 / 30) train acc: 0.972727; val_acc: 0.917098
# (Iteration 151 / 360) loss: 0.204341
# (Epoch 103 / 30) train acc: 0.976623; val_acc: 0.911917
# (Epoch 104 / 30) train acc: 0.976623; val_acc: 0.906736
# (Epoch 105 / 30) train acc: 0.974026; val_acc: 0.906736
# (Iteration 181 / 360) loss: 0.134010
# (Epoch 106 / 30) train acc: 0.979221; val_acc: 0.906736
# (Epoch 107 / 30) train acc: 0.981818; val_acc: 0.896373
# (Iteration 211 / 360) loss: 0.069952
# (Epoch 108 / 30) train acc: 0.966234; val_acc: 0.880829
# (Epoch 109 / 30) train acc: 0.980519; val_acc: 0.906736
# (Epoch 110 / 30) train acc: 0.980519; val_acc: 0.911917
# (Iteration 241 / 360) loss: 0.116464
# (Epoch 111 / 30) train acc: 0.987013; val_acc: 0.891192
# (Epoch 112 / 30) train acc: 0.990909; val_acc: 0.906736
# (Iteration 271 / 360) loss: 0.162684
# (Epoch 113 / 30) train acc: 0.989610; val_acc: 0.886010
# (Epoch 114 / 30) train acc: 0.989610; val_acc: 0.917098
# (Epoch 115 / 30) train acc: 0.988312; val_acc: 0.886010
# (Iteration 301 / 360) loss: 0.201102
# (Epoch 116 / 30) train acc: 0.989610; val_acc: 0.886010
# (Epoch 117 / 30) train acc: 0.985714; val_acc: 0.922280
# (Iteration 331 / 360) loss: 0.178084
# (Epoch 118 / 30) train acc: 0.987013; val_acc: 0.917098
# (Epoch 119 / 30) train acc: 0.989610; val_acc: 0.906736
# (Epoch 120 / 30) train acc: 0.984416; val_acc: 0.906736

# %%
plt.subplot(2, 1, 1)
plt.plot(solver.loss_history, 'o')
plt.xlabel('iteration')
plt.ylabel('loss')

plt.subplot(2, 1, 2)
plt.plot(solver.train_acc_history, '-o')
plt.plot(solver.val_acc_history, '-o')
plt.legend(['train', 'val'], loc='upper left')
plt.xlabel('epoch')
plt.ylabel('accuracy')
plt.show()

# %%
#using model to predict Validation_set
test_result=model.loss(data['X_val'])
import pandas
clasName=['min-han','mh_not','not_human']
pairVal=zip(data['y_val'],np.argmax(test_result, axis=1))
ps = pandas.Series([(clasName[i[0]],clasName[i[1]]) for i in pairVal])
counts = ps.value_counts()
print "ground_truth v.s. predict"
print counts
# Out:
# ground_truth v.s. predict
# (mh_not, mh_not)          91
# (not_human, not_human)    64
# (min-han, min-han)        20
# (min-han, mh_not)          7
# (mh_not, min-han)          4
# (not_human, mh_not)        3
# (mh_not, not_human)        2
# (not_human, min-han)       2
# dtype: int64

# %%
#visualize validation results
preIdx=np.argmax(test_result, axis=1)
wrongIdx=np.where(preIdx!=data['y_val'])
imgTemp=data['X_val'][wrongIdx]
imgLabel=data['y_val'][wrongIdx]

x_train_temp = np.empty((imgTemp.shape[0],imgTemp.shape[2],imgTemp.shape[3],imgTemp.shape[1]))
for j in range(imgTemp.shape[0]):
    for i in range(imgTemp.shape[1]):
        x_train_temp[j,:,:,i]=imgTemp[j,i,:,:]
imgTemp=x_train_temp

classes = ['min-han','not_mh','not_human']
num_classes = 3
samples_per_class = 8
for y, cls in enumerate(classes):
    idxs = np.flatnonzero(imgLabel == y)
    try:
        idxs = np.random.choice(idxs, samples_per_class, replace=False)
    except:
        pass
    for i, idx in enumerate(idxs):
        plt_idx = i * num_classes + y + 1
        plt.subplot(samples_per_class, num_classes, plt_idx)
        try:
            plt.imshow(imgTemp[idx].astype('uint8'))
        except :
            pass
        plt.axis('off')
        #if i == 0:
        plt.title(cls+"->"+classes[preIdx[wrongIdx][idx]])
plt.show()

# %%
#visualize those predicted correctly
preIdx=np.argmax(test_result, axis=1)
trueIdx=np.where(preIdx==data['y_val'])
imgTemp=data['X_val'][trueIdx]
imgLabel=data['y_val'][trueIdx]

x_train_temp = np.empty((imgTemp.shape[0],imgTemp.shape[2],imgTemp.shape[3],imgTemp.shape[1]))
for j in range(imgTemp.shape[0]):
    for i in range(imgTemp.shape[1]):
        x_train_temp[j,:,:,i]=imgTemp[j,i,:,:]
imgTemp=x_train_temp

classes = ['min-han','not_mh','not_human']
num_classes = 3
samples_per_class = 5
for y, cls in enumerate(classes):
    idxs = np.flatnonzero(imgLabel == y)
    idxs = np.random.choice(idxs, samples_per_class, replace=False)
    for i, idx in enumerate(idxs):
        plt_idx = i * num_classes + y + 1
        plt.subplot(samples_per_class, num_classes, plt_idx)
        plt.imshow(imgTemp[idx].astype('uint8'))
        plt.axis('off')
        #if i == 0:
        plt.title(cls+"->"+classes[preIdx[trueIdx][idx]])
plt.show()

# %%
#using model to predict training set
test_result=model.loss(data['X_train'])
import pandas
clasName=['min-han','mh_not','not_human']
pairVal=zip(data['y_train'],np.argmax(test_result, axis=1))
ps = pandas.Series([(clasName[i[0]],clasName[i[1]]) for i in pairVal])
counts = ps.value_counts()
print "ground_truth v.s. predict"
print counts
# Out:
# ground_truth v.s. predict
# (mh_not, mh_not)          429
# (not_human, not_human)    249
# (min-han, min-han)         80
# (not_human, mh_not)         7
# (mh_not, min-han)           2
# (mh_not, not_human)         2
# (min-han, mh_not)           1
# dtype: int64

# %%
preIdx=np.argmax(test_result, axis=1)
wrongIdx=np.where(preIdx!=data['y_train'])
imgTemp=data['X_train'][wrongIdx]
imgLabel=data['y_train'][wrongIdx]

x_train_temp = np.empty((imgTemp.shape[0],imgTemp.shape[2],imgTemp.shape[3],imgTemp.shape[1]))
for j in range(imgTemp.shape[0]):
    for i in range(imgTemp.shape[1]):
        x_train_temp[j,:,:,i]=imgTemp[j,i,:,:]
imgTemp=x_train_temp

classes = ['min-han','not_mh','not_human']
num_classes = 3
samples_per_class = 10
for y, cls in enumerate(classes):
    idxs = np.flatnonzero(imgLabel == y)
    try:
        idxs = np.random.choice(idxs, samples_per_class, replace=False)
    except:
        pass
    for i, idx in enumerate(idxs):
        plt_idx = i * num_classes + y + 1
        plt.subplot(samples_per_class, num_classes, plt_idx)
        try:
            plt.imshow(imgTemp[idx].astype('uint8'))
        except :
            pass
        plt.axis('off')
        #if i == 0:
        plt.title(cls+"->"+classes[preIdx[wrongIdx][idx]])
plt.show()

# %%
with open('Whimh_model.dkl','wb') as output:
    pickle.dump(model,output,pickle.HIGHEST_PROTOCOL)
